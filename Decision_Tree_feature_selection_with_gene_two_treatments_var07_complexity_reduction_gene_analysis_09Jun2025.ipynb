# %% [markdown]
# ## Feature selection:
# <br> Arm: Nivolumab & Everolimus
# <br> data: clinical data & gene expression data
# <br> remove the gene feature when its variances < 0.7
# <br> remove the gene feature when its high correlation > 0.4

# %% [markdown]
# ### Step0. Import Necessary Libraries

# %%
# !pip install numpy==2.2.0
# !pip install pandas==2.2.3
# !pip install scikit-learn==1.6.0
# !pip install matplotlib==3.9.3
# !pip install seaborn==0.13.2
# Out:
# Collecting numpy==2.2.0
#   Using cached numpy-2.2.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.2.0-cp312-cp312-win_amd64.whl (12.6 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-2.2.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Stella Huang\anaconda3\Lib\site-packages\~~7py.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Stella Huang\anaconda3\Lib\site-packages\~~7py'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.2.0 which is incompatible.
# numba 0.59.1 requires numpy<1.27,>=1.22, but you have numpy 2.2.0 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.2.0 which is incompatible.
# streamlit 1.32.0 requires numpy<2,>=1.19.3, but you have numpy 2.2.0 which is incompatible.
# streamlit 1.32.0 requires packaging<24,>=16.8, but you have packaging 24.1 which is incompatible.
# Requirement already satisfied: pandas==2.2.3 in c:\users\stella huang\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\stella huang\anaconda3\lib\site-packages (from pandas==2.2.3) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\stella huang\appdata\roaming\python\python312\site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\stella huang\anaconda3\lib\site-packages (from pandas==2.2.3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\stella huang\anaconda3\lib\site-packages (from pandas==2.2.3) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\stella huang\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.16.0)
# Requirement already satisfied: scikit-learn==1.6.0 in c:\users\stella huang\anaconda3\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\stella huang\anaconda3\lib\site-packages (from scikit-learn==1.6.0) (2.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\stella huang\anaconda3\lib\site-packages (from scikit-learn==1.6.0) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\stella huang\anaconda3\lib\site-packages (from scikit-learn==1.6.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\stella huang\anaconda3\lib\site-packages (from scikit-learn==1.6.0) (3.5.0)
# Requirement already satisfied: matplotlib==3.9.3 in c:\users\stella huang\anaconda3\lib\site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\stella huang\anaconda3\lib\site-packages (from matplotlib==3.9.3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\stella huang\anaconda3\lib\site-packages (from matplotlib==3.9.3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\stella huang\anaconda3\lib\site-packages (from matplotlib==3.9.3) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\stella huang\anaconda3\lib\site-packages (from matplotlib==3.9.3) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\stella huang\anaconda3\lib\site-packages (from matplotlib==3.9.3) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\stella huang\appdata\roaming\python\python312\site-packages (from matplotlib==3.9.3) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\stella huang\anaconda3\lib\site-packages (from matplotlib==3.9.3) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\stella huang\anaconda3\lib\site-packages (from matplotlib==3.9.3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\stella huang\appdata\roaming\python\python312\site-packages (from matplotlib==3.9.3) (2.9.0.post0)
# Collecting numpy>=1.23 (from matplotlib==3.9.3)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: six>=1.5 in c:\users\stella huang\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib==3.9.3) (1.16.0)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.0
#     Uninstalling numpy-2.2.0:
#       Successfully uninstalled numpy-2.2.0
# Successfully installed numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.32.0 requires packaging<24,>=16.8, but you have packaging 24.1 which is incompatible.
# Requirement already satisfied: seaborn==0.13.2 in c:\users\stella huang\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\stella huang\anaconda3\lib\site-packages (from seaborn==0.13.2) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\stella huang\anaconda3\lib\site-packages (from seaborn==0.13.2) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\stella huang\anaconda3\lib\site-packages (from seaborn==0.13.2) (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\stella huang\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\stella huang\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\stella huang\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\stella huang\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\stella huang\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\stella huang\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\stella huang\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\stella huang\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\stella huang\anaconda3\lib\site-packages (from pandas>=1.2->seaborn==0.13.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\stella huang\anaconda3\lib\site-packages (from pandas>=1.2->seaborn==0.13.2) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\stella huang\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2) (1.16.0)

# %% [markdown]
# import the necessary libraries for data processing, model training, and evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsOneClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Step1. Load the dataset and understant the categories of data

# %%
file_path = r"C:\Users\Stella Huang\Desktop\UGA\Planned Health\01_Gen&Chem\12_discussion_05Jun2025\dataset_test.csv"
data = pd.read_csv(file_path)
data.head()
# Out:
#    Cohort         Arm         MSKCC  Sarc  Rhab  Number_of_Prior_Therapies  \
# 0  CM-025   NIVOLUMAB     FAVORABLE     0     0                          1
# 1  CM-025  EVEROLIMUS     FAVORABLE     0     0                          1
# 2  CM-025  EVEROLIMUS     FAVORABLE     0     0                          2
# 3  CM-025   NIVOLUMAB  INTERMEDIATE     0     0                          1
# 4  CM-025   NIVOLUMAB  INTERMEDIATE     0     0                          1
#
#   Tumor_Sample_Primary_or_Metastasis Sex   Age   ORR  ...      UBA5     UBA52  \
# 0                         METASTASIS   M  69.0    SD  ...  34.12708  37.72089
# 1                         METASTASIS   M  61.0    SD  ...  34.51873  38.45319
# 2                            PRIMARY   M  61.0  CRPR  ...  33.93403  38.24140
# 3                            PRIMARY   M  61.0    PD  ...  34.28159  38.68207
# 4                            PRIMARY   M  59.0    SD  ...  35.16719  39.71092
#
#     UBA52P9     UCHL1  UCHL1.DT      UCP2     VEGFA  ZDHHC20P3    ZDHHC7  \
# 0  20.97768  33.51904  20.95017  35.08916  37.12501   20.95143  34.26101
# 1  20.97768  30.55278  20.95017  34.37333  37.90405   20.95143  34.75033
# 2  20.97768  35.59001  20.95017  34.55823  38.00575   20.95143  33.93191
# 3  20.97768  33.70539  24.64941  35.16243  38.85681   23.38186  34.93732
# 4  20.97768  30.91825  20.95017  33.60995  40.34498   20.95143  33.99614
#
#      ZNF433
# 0  32.57309
# 1  29.95693
# 2  31.48046
# 3  33.32286
# 4  32.66356
#
# [5 rows x 167 columns]

# %% [markdown]
# I would like to know the categories for each variable (object)

# %%
print(set(data['Arm']))
print(set(data['MSKCC']))
print(set(data['Tumor_Sample_Primary_or_Metastasis']))
print(set(data['ORR']))
print(set(data['Benefit']))
print(set(data['ExtremeResponder']))
# Out:
# {'NIVOLUMAB', 'EVEROLIMUS'}
# {'INTERMEDIATE', 'FAVORABLE', 'POOR'}
# {'METASTASIS', nan, 'PRIMARY'}
# {'CR', 'NE', 'SD', 'PR', 'PD', 'CRPR'}
# {'ICB', 'NCB', 'CB'}
# {'ER', 'PD', 'NEITHER'}

# %% [markdown]
# Check for null values, and display a summary of the dataset

# %%
# Checking for null values
# print(data.isnull().sum())
## data.isnull(): check if there is any NaN in data
## .sum(): sumerize the number of TRUE (if TRUE means NaN), calculate how many NaN in the column

# Dataset summary
print(data.info())
## .info(): showing tyoe and non-null amount
#print(data.describe())
## .describe():statistic info: count, mean, std, min, 25%, 50%, 75%, max

print(data.info(verbose=True, show_counts=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Columns: 167 entries, Cohort to ZNF433
# dtypes: float64(154), int64(5), object(8)
# memory usage: 373.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Data columns (total 167 columns):
#  #    Column                              Non-Null Count  Dtype
# ---   ------                              --------------  -----
#  0    Cohort                              286 non-null    object
#  1    Arm                                 286 non-null    object
#  2    MSKCC                               286 non-null    object
#  3    Sarc                                286 non-null    int64
#  4    Rhab                                286 non-null    int64
#  5    Number_of_Prior_Therapies           286 non-null    int64
#  6    Tumor_Sample_Primary_or_Metastasis  284 non-null    object
#  7    Sex                                 286 non-null    object
#  8    Age                                 286 non-null    float64
#  9    ORR                                 286 non-null    object
#  10   Benefit                             286 non-null    object
#  11   ExtremeResponder                    286 non-null    object
#  12   PFS                                 286 non-null    float64
#  13   PFS_CNSR                            286 non-null    int64
#  14   OS                                  286 non-null    float64
#  15   OS_CNSR                             286 non-null    int64
#  16   ACAP1                               286 non-null    float64
#  17   ACCS                                286 non-null    float64
#  18   ACCSL                               286 non-null    float64
#  19   ADCY5                               286 non-null    float64
#  20   AHRR                                286 non-null    float64
#  21   AK3P4                               286 non-null    float64
#  22   ARHGAP42                            286 non-null    float64
#  23   ARPC1B                              286 non-null    float64
#  24   ATP6V1G1P2                          286 non-null    float64
#  25   ATXN3L                              286 non-null    float64
#  26   BARX2                               286 non-null    float64
#  27   BICD1                               286 non-null    float64
#  28   BICD1P1                             286 non-null    float64
#  29   BMAL2.AS1                           286 non-null    float64
#  30   BPY2B                               286 non-null    float64
#  31   BTBD10                              286 non-null    float64
#  32   BTBD10P1                            286 non-null    float64
#  33   C3orf20                             286 non-null    float64
#  34   CACNA1A                             286 non-null    float64
#  35   CACNG2                              286 non-null    float64
#  36   CAP1                                286 non-null    float64
#  37   CAP1P2                              286 non-null    float64
#  38   CAPN15                              286 non-null    float64
#  39   CCDC146                             286 non-null    float64
#  40   CCDC30                              286 non-null    float64
#  41   CCT7                                286 non-null    float64
#  42   CCT7P1                              286 non-null    float64
#  43   CCT7P2                              286 non-null    float64
#  44   CDS1                                286 non-null    float64
#  45   CEACAM6                             286 non-null    float64
#  46   CHST4                               286 non-null    float64
#  47   CLDN6                               286 non-null    float64
#  48   CLSPN                               286 non-null    float64
#  49   CNR1                                286 non-null    float64
#  50   COPS6                               286 non-null    float64
#  51   CPPED1                              286 non-null    float64
#  52   CRPP1                               286 non-null    float64
#  53   CUL9                                286 non-null    float64
#  54   CYSRT1                              286 non-null    float64
#  55   DCAF1                               286 non-null    float64
#  56   DCAF10                              286 non-null    float64
#  57   DCAF11                              286 non-null    float64
#  58   DCAF12                              286 non-null    float64
#  59   DCAF12L1                            286 non-null    float64
#  60   DCAF12L2                            286 non-null    float64
#  61   DCAF13                              286 non-null    float64
#  62   DCAF13P1                            286 non-null    float64
#  63   DCAF15                              286 non-null    float64
#  64   DCAF16                              286 non-null    float64
#  65   DCAF17                              286 non-null    float64
#  66   DDHD1.DT                            286 non-null    float64
#  67   DLGAP5                              286 non-null    float64
#  68   DOC2A                               286 non-null    float64
#  69   DPH5                                286 non-null    float64
#  70   DPH5.DT                             286 non-null    float64
#  71   DPP4                                286 non-null    float64
#  72   DPP9                                286 non-null    float64
#  73   DPP9.AS1                            286 non-null    float64
#  74   DSPP                                286 non-null    float64
#  75   ENAHP1                              286 non-null    float64
#  76   ENAM                                286 non-null    float64
#  77   EPHB2                               286 non-null    float64
#  78   EXO1                                286 non-null    float64
#  79   FALEC                               286 non-null    float64
#  80   FAM13A                              286 non-null    float64
#  81   FAM13A.AS1                          286 non-null    float64
#  82   FAM170A                             286 non-null    float64
#  83   FAM174A                             286 non-null    float64
#  84   FAM174A.DT                          286 non-null    float64
#  85   FAM187B2P                           286 non-null    float64
#  86   FAUP3                               286 non-null    float64
#  87   FLT3                                286 non-null    float64
#  88   FLT3LG                              286 non-null    float64
#  89   FOCAD.AS1                           286 non-null    float64
#  90   FTHL17                              286 non-null    float64
#  91   GADD45A                             286 non-null    float64
#  92   GAGE2C                              286 non-null    float64
#  93   GAGE2E                              286 non-null    float64
#  94   GAGE4                               286 non-null    float64
#  95   GCOM1                               286 non-null    float64
#  96   GIT2                                286 non-null    float64
#  97   GOT2                                286 non-null    float64
#  98   GOT2P1                              286 non-null    float64
#  99   GOT2P3                              286 non-null    float64
#  100  GPR42                               286 non-null    float64
#  101  GTF2IRD1                            286 non-null    float64
#  102  HECTD2                              286 non-null    float64
#  103  HFM1                                286 non-null    float64
#  104  HILPDA                              286 non-null    float64
#  105  HLA.DRB1                            286 non-null    float64
#  106  HLA.G                               286 non-null    float64
#  107  KRBA2                               286 non-null    float64
#  108  KRTAP2.3                            286 non-null    float64
#  109  L1CAM                               286 non-null    float64
#  110  LINC00994                           286 non-null    float64
#  111  LINC01307                           286 non-null    float64
#  112  LINC01396                           286 non-null    float64
#  113  LOC107984203                        286 non-null    float64
#  114  LRRC3                               286 non-null    float64
#  115  LRRC30                              286 non-null    float64
#  116  LRRC31                              286 non-null    float64
#  117  LRRC32                              286 non-null    float64
#  118  LRRC34                              286 non-null    float64
#  119  LRRC36                              286 non-null    float64
#  120  LRRC37A                             286 non-null    float64
#  121  LRRC37A13P                          286 non-null    float64
#  122  LRRC37A14P                          286 non-null    float64
#  123  LRRC37A15P                          286 non-null    float64
#  124  LRRC37A17P                          286 non-null    float64
#  125  LRRC37A2                            286 non-null    float64
#  126  LRRC37A3                            286 non-null    float64
#  127  LRRC37A6P                           286 non-null    float64
#  128  LRRC37B                             286 non-null    float64
#  129  LRRC38                              286 non-null    float64
#  130  LRRC39                              286 non-null    float64
#  131  LRRC3B                              286 non-null    float64
#  132  LRRC3C                              286 non-null    float64
#  133  MASP1                               286 non-null    float64
#  134  MATCAP1                             286 non-null    float64
#  135  MIMT1                               286 non-null    float64
#  136  MIR572                              286 non-null    float64
#  137  MOAP1                               286 non-null    float64
#  138  MYOC                                286 non-null    float64
#  139  MYOCD                               286 non-null    float64
#  140  NECAP1                              286 non-null    float64
#  141  NECAP1P2                            286 non-null    float64
#  142  PLIN2                               286 non-null    float64
#  143  PSMC1P10                            286 non-null    float64
#  144  RAB3B                               286 non-null    float64
#  145  REXO1                               286 non-null    float64
#  146  RN7SL454P                           286 non-null    float64
#  147  RN7SL638P                           286 non-null    float64
#  148  RNU4.30P                            286 non-null    float64
#  149  RNU4.32P                            286 non-null    float64
#  150  RPL6P5                              286 non-null    float64
#  151  S100A6                              286 non-null    float64
#  152  SIMC1                               286 non-null    float64
#  153  SLC25A39                            286 non-null    float64
#  154  SUCNR1                              286 non-null    float64
#  155  TENM3                               286 non-null    float64
#  156  TSSK3                               286 non-null    float64
#  157  UBA5                                286 non-null    float64
#  158  UBA52                               286 non-null    float64
#  159  UBA52P9                             286 non-null    float64
#  160  UCHL1                               286 non-null    float64
#  161  UCHL1.DT                            286 non-null    float64
#  162  UCP2                                286 non-null    float64
#  163  VEGFA                               286 non-null    float64
#  164  ZDHHC20P3                           286 non-null    float64
#  165  ZDHHC7                              286 non-null    float64
#  166  ZNF433                              286 non-null    float64
# dtypes: float64(154), int64(5), object(8)
# memory usage: 373.3+ KB
# None

# %% [markdown]
# ### Step2. Data pre-processing

# %% [markdown]
# Remove outcome-related features to prevent data leakage

# %%
leakage_cols = ['Cohort', 'Benefit', 'ExtremeResponder', 'OS', 'OS_CNSR', 'PFS', 'PFS_CNSR']
data = data.drop(columns=leakage_cols)  # Added: drop columns that cause data leakage

# %% [markdown]
# See the Distribution of ORR

# %%
orr_counts = data["ORR"].value_counts()
plt.figure(figsize=(6,4))
orr_counts.plot(kind="bar")
plt.xlabel("ORR (Response Categories)")
plt.ylabel("Number of Patients")
plt.title("Distribution of ORR (Objective Response Rate)")
plt.xticks(rotation=0)
plt.show()
orr_counts
# Out:
# ORR
# SD      121
# PD       98
# NE       29
# CRPR     27
# PR       10
# CR        1
# Name: count, dtype: int64

# %% [markdown]
# Transfer ORR to binary classification:
# <br> Responder (1): "CRPR", "CR","PR"
# <br> NON-Responder (0): "PD", "SD"
# <br> Remove "NE" (non-evaluate)

# %%
# transfer ORR to binary classification
data = data[data["ORR"] != "NE"]  # remove "NE", !=(not equal)
data["ORR_binary"] = data["ORR"].apply(lambda x: 1 if x in ["CRPR", "CR","PR"] else 0)
## data["ORR_binary"] : create a new column "ORR_binary" for saving the binary result
## .apply(...) : apply a function, which will let all value in ORR to transfer, and the function is lambda
## lambda x: it is an anonymous function, x means every value in ORR
### if x in ["CRPR", "CR"] : check if x belongs to ["CRPR", "CR"], if TRUE then 1(Responder), else 0(Non-Responder)

# check the result
data["ORR_binary"].value_counts()
## .value_counts(): count how many times of 1 and 0 in "ORR_binary"
# Out:
# ORR_binary
# 0    219
# 1     38
# Name: count, dtype: int64

# %% [markdown]
# Because some data ("Tumor_Sample_Primary_or_Metastasis", "Sex") is object, I used One-Hot Encoding to transfer object to int.

# %%
# Apply One-Hot Encoding to categorical variables
data = pd.get_dummies(data, columns=["Arm", "Tumor_Sample_Primary_or_Metastasis", "Sex", 
                                 ], drop_first=True)

# Check the new dataset structure
print(data.head())
# Out:
#           MSKCC  Sarc  Rhab  Number_of_Prior_Therapies   Age   ORR     ACAP1  \
# 0     FAVORABLE     0     0                          1  69.0    SD  33.99747
# 1     FAVORABLE     0     0                          1  61.0    SD  31.71281
# 2     FAVORABLE     0     0                          2  61.0  CRPR  31.73848
# 3  INTERMEDIATE     0     0                          1  61.0    PD  30.55362
# 4  INTERMEDIATE     0     0                          1  59.0    SD  31.11186
#
#        ACCS     ACCSL     ADCY5  ...  UCHL1.DT      UCP2     VEGFA  ZDHHC20P3  \
# 0  32.20615  24.06116  30.91315  ...  20.95017  35.08916  37.12501   20.95143
# 1  32.80117  20.57774  30.87107  ...  20.95017  34.37333  37.90405   20.95143
# 2  32.27727  20.57774  32.29066  ...  20.95017  34.55823  38.00575   20.95143
# 3  32.44389  23.35166  34.22764  ...  24.64941  35.16243  38.85681   23.38186
# 4  30.61340  20.57774  33.46771  ...  20.95017  33.60995  40.34498   20.95143
#
#      ZDHHC7    ZNF433  ORR_binary  Arm_NIVOLUMAB  \
# 0  34.26101  32.57309           0           True
# 1  34.75033  29.95693           0          False
# 2  33.93191  31.48046           1          False
# 3  34.93732  33.32286           0           True
# 4  33.99614  32.66356           0           True
#
#    Tumor_Sample_Primary_or_Metastasis_PRIMARY  Sex_M
# 0                                       False   True
# 1                                       False   True
# 2                                        True   True
# 3                                        True   True
# 4                                        True   True
#
# [5 rows x 161 columns]

# %% [markdown]
# And 'MSKCC' is sequential, I define them as FAVORABLE = 2, INTERMEDIATE = 1, POOR = 0<br>
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.map.html

# %%
mskcc_map = {
    'POOR': 0,
    'INTERMEDIATE': 1,
    'FAVORABLE': 2
}

data['MSKCC_num'] = data['MSKCC'].map(mskcc_map)

# %% [markdown]
# ### Step3. Feature selection

# %% [markdown]
# Remove genes with low variance (VarianceThreshold) <br>
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.VarianceThreshold.html

# %%
gene_features = ["ACAP1","ACCS","ACCSL","ADCY5","AHRR","AK3P4","ARHGAP42","ARPC1B","ATP6V1G1P2","ATXN3L","BARX2","BICD1","BICD1P1","BMAL2.AS1","BPY2B","BTBD10","BTBD10P1","C3orf20","CACNA1A","CACNG2","CAP1","CAP1P2","CAPN15","CCDC146","CCDC30","CCT7","CCT7P1","CCT7P2","CDS1","CEACAM6","CHST4","CLDN6","CLSPN","CNR1","COPS6","CPPED1","CRPP1","CUL9","CYSRT1","DCAF1","DCAF10","DCAF11","DCAF12","DCAF12L1","DCAF12L2","DCAF13","DCAF13P1","DCAF15","DCAF16","DCAF17","DDHD1.DT","DLGAP5","DOC2A","DPH5","DPH5.DT","DPP4","DPP9","DPP9.AS1","DSPP","ENAHP1","ENAM","EPHB2","EXO1","FALEC","FAM13A","FAM13A.AS1","FAM170A","FAM174A","FAM174A.DT","FAM187B2P","FAUP3","FLT3","FLT3LG","FOCAD.AS1","FTHL17","GADD45A","GAGE2C","GAGE2E","GAGE4","GCOM1","GIT2","GOT2","GOT2P1","GOT2P3","GPR42","GTF2IRD1","HECTD2","HFM1","HILPDA","HLA.DRB1","HLA.G","KRBA2","KRTAP2.3","L1CAM","LINC00994","LINC01307","LINC01396","LOC107984203","LRRC3","LRRC30","LRRC31","LRRC32","LRRC34","LRRC36","LRRC37A","LRRC37A13P","LRRC37A14P","LRRC37A15P","LRRC37A17P","LRRC37A2","LRRC37A3","LRRC37A6P","LRRC37B","LRRC38","LRRC39","LRRC3B","LRRC3C","MASP1","MATCAP1","MIMT1","MIR572","MOAP1","MYOC","MYOCD","NECAP1","NECAP1P2","PLIN2","PSMC1P10","RAB3B","REXO1","RN7SL454P","RN7SL638P","RNU4.30P","RNU4.32P","RPL6P5","S100A6","SIMC1","SLC25A39","SUCNR1","TENM3","TSSK3","UBA5","UBA52","UBA52P9","UCHL1","UCHL1.DT","UCP2","VEGFA","ZDHHC20P3","ZDHHC7","ZNF433"]

# %% [markdown]
# To see the distribution of the gene expression values

# %%
# Select only the gene feature columns from the DataFrame
gene_df = data[gene_features]
variances = gene_df.var()
print(variances.sort_values())  # from low to high
# Out:
# MIMT1            0.000233
# LOC107984203     0.000341
# FAUP3            0.000590
# RNU4.30P         0.000737
# GAGE2C           0.000941
#                   ...
# LRRC31           9.502287
# CYSRT1           9.729294
# CEACAM6         10.753839
# DCAF12L1        11.266220
# LRRC37A14P      16.046435
# Length: 151, dtype: float64

# %%
min_val = variances.min() 
max_val = variances.max()
bins = np.arange(min_val, max_val + 0.1, 0.1) 

plt.figure(figsize=(27, 6))
plt.hist(variances, bins=bins, color='skyblue', edgecolor='black')
plt.xlabel('Variance')
plt.ylabel('Number of Genes')
plt.title('Histogram of Gene Expression Variances_two treatments')
plt.xticks(np.round(bins, 1), rotation=90)
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# I would like to know in each range, which genes are included?

# %%
variances = gene_df.var()

for i in range(0, 160):  # 0 to 16
    lower = i / 10
    upper = (i + 1) / 10
    genes_in_bin = variances[(variances >= lower) & (variances < upper)].index.tolist()
    print(f"{lower:.1f} <= Variance < {upper:.1f}:", genes_in_bin)
# Out:
# 0.0 <= Variance < 0.1: ['AK3P4', 'FAUP3', 'GAGE2C', 'GAGE4', 'LINC00994', 'LINC01307', 'LINC01396', 'LOC107984203', 'MIMT1', 'MIR572', 'RN7SL638P', 'RNU4.30P', 'RPL6P5', 'UBA52P9', 'ZDHHC20P3']
# 0.1 <= Variance < 0.2: ['ATP6V1G1P2', 'BICD1P1', 'DCAF1']
# 0.2 <= Variance < 0.3: ['CAP1', 'CCT7', 'COPS6', 'DDHD1.DT', 'FTHL17']
# 0.3 <= Variance < 0.4: ['BTBD10', 'GIT2', 'LRRC37A17P', 'NECAP1', 'RN7SL454P', 'UCHL1.DT', 'ZDHHC7']
# 0.4 <= Variance < 0.5: ['CAPN15', 'CUL9', 'DCAF16', 'FAM174A.DT', 'MOAP1', 'RNU4.32P', 'UBA52']
# 0.5 <= Variance < 0.6: ['DCAF10', 'DCAF15', 'DCAF17', 'DPH5', 'DPP9', 'FALEC', 'FAM187B2P', 'HECTD2', 'LRRC37B', 'REXO1', 'SLC25A39', 'UBA5']
# 0.6 <= Variance < 0.7: ['ARPC1B', 'DCAF11', 'DCAF12', 'DCAF13', 'FAM13A', 'FOCAD.AS1', 'GOT2', 'GTF2IRD1']
# 0.7 <= Variance < 0.8: ['ACCS', 'BICD1', 'FAM174A', 'LRRC37A3', 'SIMC1']
# 0.8 <= Variance < 0.9: ['BMAL2.AS1', 'CPPED1', 'GOT2P1', 'KRBA2']
# 0.9 <= Variance < 1.0: ['ARHGAP42', 'LRRC32', 'S100A6']
# 1.0 <= Variance < 1.1: ['CRPP1', 'UCP2']
# 1.1 <= Variance < 1.2: ['HLA.DRB1', 'LRRC30']
# 1.2 <= Variance < 1.3: ['CACNG2', 'GADD45A', 'LRRC37A', 'ZNF433']
# 1.3 <= Variance < 1.4: ['ACAP1', 'GAGE2E', 'LRRC3C']
# 1.4 <= Variance < 1.5: ['CLSPN', 'VEGFA']
# 1.5 <= Variance < 1.6: ['CCT7P2', 'MATCAP1']
# 1.6 <= Variance < 1.7: ['LRRC37A2']
# 1.7 <= Variance < 1.8: ['CCDC30', 'EPHB2']
# 1.8 <= Variance < 1.9: ['NECAP1P2', 'PLIN2']
# 1.9 <= Variance < 2.0: []
# 2.0 <= Variance < 2.1: ['DPH5.DT', 'DPP4', 'LRRC38']
# 2.1 <= Variance < 2.2: ['DLGAP5', 'FLT3LG']
# 2.2 <= Variance < 2.3: ['HILPDA', 'LRRC37A6P']
# 2.3 <= Variance < 2.4: ['ATXN3L']
# 2.4 <= Variance < 2.5: []
# 2.5 <= Variance < 2.6: ['LRRC37A15P']
# 2.6 <= Variance < 2.7: []
# 2.7 <= Variance < 2.8: ['CCDC146']
# 2.8 <= Variance < 2.9: ['CLDN6']
# 2.9 <= Variance < 3.0: []
# 3.0 <= Variance < 3.1: ['ACCSL', 'CDS1']
# 3.1 <= Variance < 3.2: []
# 3.2 <= Variance < 3.3: ['TSSK3']
# 3.3 <= Variance < 3.4: ['BTBD10P1']
# 3.4 <= Variance < 3.5: []
# 3.5 <= Variance < 3.6: ['ENAHP1']
# 3.6 <= Variance < 3.7: ['ADCY5', 'DPP9.AS1']
# 3.7 <= Variance < 3.8: []
# 3.8 <= Variance < 3.9: ['EXO1']
# 3.9 <= Variance < 4.0: []
# 4.0 <= Variance < 4.1: []
# 4.1 <= Variance < 4.2: ['CCT7P1']
# 4.2 <= Variance < 4.3: []
# 4.3 <= Variance < 4.4: ['MASP1']
# 4.4 <= Variance < 4.5: ['CAP1P2', 'PSMC1P10', 'SUCNR1']
# 4.5 <= Variance < 4.6: ['AHRR']
# 4.6 <= Variance < 4.7: ['DCAF13P1', 'RAB3B']
# 4.7 <= Variance < 4.8: []
# 4.8 <= Variance < 4.9: ['FAM170A']
# 4.9 <= Variance < 5.0: []
# 5.0 <= Variance < 5.1: ['FAM13A.AS1', 'LRRC39']
# 5.1 <= Variance < 5.2: ['FLT3', 'LRRC34', 'LRRC37A13P', 'TENM3']
# 5.2 <= Variance < 5.3: []
# 5.3 <= Variance < 5.4: []
# 5.4 <= Variance < 5.5: []
# 5.5 <= Variance < 5.6: ['BARX2']
# 5.6 <= Variance < 5.7: ['CACNA1A', 'KRTAP2.3']
# 5.7 <= Variance < 5.8: ['GOT2P3', 'LRRC3B']
# 5.8 <= Variance < 5.9: []
# 5.9 <= Variance < 6.0: []
# 6.0 <= Variance < 6.1: ['LRRC3']
# 6.1 <= Variance < 6.2: []
# 6.2 <= Variance < 6.3: ['LRRC36']
# 6.3 <= Variance < 6.4: ['HFM1']
# 6.4 <= Variance < 6.5: ['DOC2A']
# 6.5 <= Variance < 6.6: []
# 6.6 <= Variance < 6.7: ['UCHL1']
# 6.7 <= Variance < 6.8: []
# 6.8 <= Variance < 6.9: []
# 6.9 <= Variance < 7.0: []
# 7.0 <= Variance < 7.1: []
# 7.1 <= Variance < 7.2: ['CNR1']
# 7.2 <= Variance < 7.3: []
# 7.3 <= Variance < 7.4: []
# 7.4 <= Variance < 7.5: ['DSPP']
# 7.5 <= Variance < 7.6: ['ENAM', 'HLA.G']
# 7.6 <= Variance < 7.7: ['GCOM1']
# 7.7 <= Variance < 7.8: []
# 7.8 <= Variance < 7.9: ['BPY2B', 'L1CAM', 'MYOC']
# 7.9 <= Variance < 8.0: []
# 8.0 <= Variance < 8.1: ['C3orf20']
# 8.1 <= Variance < 8.2: ['MYOCD']
# 8.2 <= Variance < 8.3: ['DCAF12L2']
# 8.3 <= Variance < 8.4: []
# 8.4 <= Variance < 8.5: []
# 8.5 <= Variance < 8.6: []
# 8.6 <= Variance < 8.7: []
# 8.7 <= Variance < 8.8: []
# 8.8 <= Variance < 8.9: []
# 8.9 <= Variance < 9.0: []
# 9.0 <= Variance < 9.1: ['CHST4']
# 9.1 <= Variance < 9.2: ['GPR42']
# 9.2 <= Variance < 9.3: []
# 9.3 <= Variance < 9.4: []
# 9.4 <= Variance < 9.5: []
# 9.5 <= Variance < 9.6: ['LRRC31']
# 9.6 <= Variance < 9.7: []
# 9.7 <= Variance < 9.8: ['CYSRT1']
# 9.8 <= Variance < 9.9: []
# 9.9 <= Variance < 10.0: []
# 10.0 <= Variance < 10.1: []
# 10.1 <= Variance < 10.2: []
# 10.2 <= Variance < 10.3: []
# 10.3 <= Variance < 10.4: []
# 10.4 <= Variance < 10.5: []
# 10.5 <= Variance < 10.6: []
# 10.6 <= Variance < 10.7: []
# 10.7 <= Variance < 10.8: ['CEACAM6']
# 10.8 <= Variance < 10.9: []
# 10.9 <= Variance < 11.0: []
# 11.0 <= Variance < 11.1: []
# 11.1 <= Variance < 11.2: []
# 11.2 <= Variance < 11.3: ['DCAF12L1']
# 11.3 <= Variance < 11.4: []
# 11.4 <= Variance < 11.5: []
# 11.5 <= Variance < 11.6: []
# 11.6 <= Variance < 11.7: []
# 11.7 <= Variance < 11.8: []
# 11.8 <= Variance < 11.9: []
# 11.9 <= Variance < 12.0: []
# 12.0 <= Variance < 12.1: []
# 12.1 <= Variance < 12.2: []
# 12.2 <= Variance < 12.3: []
# 12.3 <= Variance < 12.4: []
# 12.4 <= Variance < 12.5: []
# 12.5 <= Variance < 12.6: []
# 12.6 <= Variance < 12.7: []
# 12.7 <= Variance < 12.8: []
# 12.8 <= Variance < 12.9: []
# 12.9 <= Variance < 13.0: []
# 13.0 <= Variance < 13.1: []
# 13.1 <= Variance < 13.2: []
# 13.2 <= Variance < 13.3: []
# 13.3 <= Variance < 13.4: []
# 13.4 <= Variance < 13.5: []
# 13.5 <= Variance < 13.6: []
# 13.6 <= Variance < 13.7: []
# 13.7 <= Variance < 13.8: []
# 13.8 <= Variance < 13.9: []
# 13.9 <= Variance < 14.0: []
# 14.0 <= Variance < 14.1: []
# 14.1 <= Variance < 14.2: []
# 14.2 <= Variance < 14.3: []
# 14.3 <= Variance < 14.4: []
# 14.4 <= Variance < 14.5: []
# 14.5 <= Variance < 14.6: []
# 14.6 <= Variance < 14.7: []
# 14.7 <= Variance < 14.8: []
# 14.8 <= Variance < 14.9: []
# 14.9 <= Variance < 15.0: []
# 15.0 <= Variance < 15.1: []
# 15.1 <= Variance < 15.2: []
# 15.2 <= Variance < 15.3: []
# 15.3 <= Variance < 15.4: []
# 15.4 <= Variance < 15.5: []
# 15.5 <= Variance < 15.6: []
# 15.6 <= Variance < 15.7: []
# 15.7 <= Variance < 15.8: []
# 15.8 <= Variance < 15.9: []
# 15.9 <= Variance < 16.0: []

# %% [markdown]
# What is the median of gene variances?

# %%
median_variance = variances.median()
print("Median of gene variances:", median_variance)
# Out:
# Median of gene variances: 1.2583797803945258

# %% [markdown]
# How many genes below variance= 0.1, 0.5, 0.7, 1.2583797803945258

# %%
# Count the number of genes with variance below and equal 0.1, 0.5, 0.7, 1.184
num_genes_below_01 = (variances <= 0.1).sum()
print("Number of genes with variance below 0.1:", num_genes_below_01)

num_genes_below_05 = (variances <= 0.5).sum()
print("Number of genes with variance below 0.5:", num_genes_below_05)

num_genes_below_07 = (variances <= 0.7).sum()
print("Number of genes with variance below 0.7:", num_genes_below_07)

num_genes_below_1_184 = (variances <= 1.2583797803945258).sum()
print("Number of genes with variance below 1.2583797803945258:", num_genes_below_1_184)
# Out:
# Number of genes with variance below 0.1: 15
# Number of genes with variance below 0.5: 37
# Number of genes with variance below 0.7: 57
# Number of genes with variance below 1.2583797803945258: 76

# %% [markdown]
# Setting threshold=0.5, apply VarianceThreshold

# %%
from sklearn.feature_selection import VarianceThreshold

# Select only the gene feature columns from the DataFrame
gene_df = data[gene_features]

# Remove features with low variance from gene_df
selector = VarianceThreshold(threshold=0.7)  # Set the threshold to 0.5
X_high_variance = selector.fit_transform(gene_df)

# Optional: Get the names of the selected features
# Use gene_df.columns to get the column names of the selected features
selected_columns = gene_df.columns[selector.get_support()]
X_high_variance_df = pd.DataFrame(X_high_variance, columns=selected_columns)

# Print the shape of the original and reduced DataFrames
print("Original shape:", gene_df.shape)
print("Reduced shape:", X_high_variance_df.shape)
# Print the selected columns
print("Selected columns:", selected_columns)
# Out:
# Original shape: (257, 151)
# Reduced shape: (257, 94)
# Selected columns: Index(['ACAP1', 'ACCS', 'ACCSL', 'ADCY5', 'AHRR', 'ARHGAP42', 'ATXN3L',
#        'BARX2', 'BICD1', 'BMAL2.AS1', 'BPY2B', 'BTBD10P1', 'C3orf20',
#        'CACNA1A', 'CACNG2', 'CAP1P2', 'CCDC146', 'CCDC30', 'CCT7P1', 'CCT7P2',
#        'CDS1', 'CEACAM6', 'CHST4', 'CLDN6', 'CLSPN', 'CNR1', 'CPPED1', 'CRPP1',
#        'CYSRT1', 'DCAF12L1', 'DCAF12L2', 'DCAF13P1', 'DLGAP5', 'DOC2A',
#        'DPH5.DT', 'DPP4', 'DPP9.AS1', 'DSPP', 'ENAHP1', 'ENAM', 'EPHB2',
#        'EXO1', 'FAM13A.AS1', 'FAM170A', 'FAM174A', 'FLT3', 'FLT3LG', 'GADD45A',
#        'GAGE2E', 'GCOM1', 'GOT2P1', 'GOT2P3', 'GPR42', 'HFM1', 'HILPDA',
#        'HLA.DRB1', 'HLA.G', 'KRBA2', 'KRTAP2.3', 'L1CAM', 'LRRC3', 'LRRC30',
#        'LRRC31', 'LRRC32', 'LRRC34', 'LRRC36', 'LRRC37A', 'LRRC37A13P',
#        'LRRC37A14P', 'LRRC37A15P', 'LRRC37A2', 'LRRC37A3', 'LRRC37A6P',
#        'LRRC38', 'LRRC39', 'LRRC3B', 'LRRC3C', 'MASP1', 'MATCAP1', 'MYOC',
#        'MYOCD', 'NECAP1P2', 'PLIN2', 'PSMC1P10', 'RAB3B', 'S100A6', 'SIMC1',
#        'SUCNR1', 'TENM3', 'TSSK3', 'UCHL1', 'UCP2', 'VEGFA', 'ZNF433'],
#       dtype='object')

# %% [markdown]
# Apply Correlation-based Feature Selection

# %%
import seaborn as sns
import scipy.cluster.hierarchy as sch
from scipy.spatial.distance import pdist, squareform

# Select only the gene feature columns from the DataFrame
# After VarianceThreshold
gene_df_high_var = X_high_variance_df.copy() 

# calculate the distance matrix
corr = gene_df_high_var.corr().abs()  # abs() to get the absolute value
# 1 - correlation to get distance
distance = 1 - corr
# linkage = sch.linkage(squareform(distance), method='average')  # average linkage

# create a dendrogram to decide the number of clusters
sns.clustermap(corr, cmap="vlag", figsize=(10,10))

# %% [markdown]
# Select gene from correlation heatmap

# %%
# Step 1: calculate the correlation matrix
# calculate the pearson correlation matrix between the gene features
corr_matrix = gene_df_high_var.corr().abs()

# Step 2: get the upper triangle of the correlation matrix
# keep only the upper triangle of the correlation matrix
# to avoid duplicate calculations and the diagonal (self-correlation)
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# step 3: create a list to keep the columns (keep the one with the highest variance in each group)
# set the threshold for correlation
threshold = 0.4
to_keep = set()
already_seen = set()

# loop through the columns of the upper triangle matrix
for col in upper.columns:
    if col not in already_seen:
        # find other genes that are highly correlated with col
        high_corr = upper[col][upper[col] > threshold].index.tolist()
        high_corr.append(col)
        
        # find the one with the ""highest""" variance in this group
        best_gene = gene_df_high_var[high_corr].var().idxmax()
        ### best_gene: the representative gene in the group
        to_keep.add(best_gene) # keep the representative gene in each group (the list of best_genes)
        already_seen.update(high_corr)

# Step 4: keep the filtered genes
gene_df_filtered = gene_df[list(to_keep)]

# Print the shape of the original and filtered DataFrames
print("Original shape:", gene_df.shape)
print("Filtered shape:", gene_df_filtered.shape)
# Print the selected columns
print("Final selected gene columns:", to_keep) ## genes kept after correlation filtering


# chech the maximum correlation
print("Max correlation among genes:", upper.max().max())

# See how many genes are highly correlated (> threshold)
# print(f"how many genes (>{threshold}):", sum((upper > threshold).sum() > 0)) 
### sum((upper > threshold).sum() > 0): count how many genes have at least one other gene with correlation > threshold

# How many genes are kept
print(f"Number of genes kept: {len(to_keep)}")

# which genes are removed
removed_genes = set(gene_df.columns) - set(to_keep)
print(f"Removed genes ({len(removed_genes)}):", removed_genes)
# Out:
# Original shape: (257, 151)
# Filtered shape: (257, 87)
# Final selected gene columns: {'LRRC37A2', 'DCAF12L1', 'LRRC30', 'AHRR', 'CACNA1A', 'GADD45A', 'GPR42', 'ADCY5', 'LRRC34', 'ENAM', 'FLT3LG', 'LRRC3B', 'LRRC39', 'C3orf20', 'CHST4', 'BARX2', 'DSPP', 'DCAF12L2', 'CLDN6', 'EPHB2', 'EXO1', 'LRRC3C', 'BICD1', 'GOT2P1', 'CCDC146', 'CLSPN', 'LRRC37A13P', 'LRRC32', 'SUCNR1', 'L1CAM', 'CDS1', 'LRRC37A', 'GCOM1', 'LRRC36', 'SIMC1', 'ZNF433', 'NECAP1P2', 'CCT7P1', 'DPH5.DT', 'FAM170A', 'LRRC37A6P', 'UCHL1', 'BPY2B', 'GOT2P3', 'CACNG2', 'LRRC37A14P', 'FLT3', 'DPP4', 'PSMC1P10', 'CPPED1', 'KRTAP2.3', 'TENM3', 'ACCSL', 'ARHGAP42', 'MYOCD', 'CRPP1', 'LRRC38', 'ACAP1', 'HFM1', 'KRBA2', 'MYOC', 'DPP9.AS1', 'CCT7P2', 'LRRC31', 'LRRC37A3', 'DCAF13P1', 'MASP1', 'BTBD10P1', 'CNR1', 'TSSK3', 'CCDC30', 'DOC2A', 'BMAL2.AS1', 'LRRC37A15P', 'CEACAM6', 'LRRC3', 'CAP1P2', 'CYSRT1', 'FAM174A', 'ATXN3L', 'RAB3B', 'HLA.G', 'DLGAP5', 'ENAHP1', 'ACCS', 'FAM13A.AS1', 'GAGE2E'}
# Max correlation among genes: 0.5832014708987462
# Number of genes kept: 87
# Removed genes (64): {'MIMT1', 'CCT7', 'ZDHHC20P3', 'S100A6', 'ARPC1B', 'LINC01307', 'DDHD1.DT', 'FAM187B2P', 'DCAF16', 'UBA5', 'FOCAD.AS1', 'HILPDA', 'DCAF12', 'LRRC37A17P', 'CUL9', 'AK3P4', 'FAM174A.DT', 'REXO1', 'DCAF13', 'MOAP1', 'DCAF11', 'DCAF10', 'UCP2', 'MATCAP1', 'FTHL17', 'SLC25A39', 'HECTD2', 'RNU4.30P', 'COPS6', 'DCAF1', 'MIR572', 'CAP1', 'UBA52P9', 'HLA.DRB1', 'RNU4.32P', 'UBA52', 'FAM13A', 'VEGFA', 'RN7SL638P', 'LINC00994', 'DPH5', 'DCAF17', 'GOT2', 'GAGE4', 'FAUP3', 'PLIN2', 'LOC107984203', 'DCAF15', 'UCHL1.DT', 'CAPN15', 'ATP6V1G1P2', 'DPP9', 'GIT2', 'RPL6P5', 'NECAP1', 'RN7SL454P', 'BICD1P1', 'ZDHHC7', 'GTF2IRD1', 'LRRC37B', 'BTBD10', 'LINC01396', 'GAGE2C', 'FALEC'}

# %% [markdown]
# Dimensionality reduction + visualization using t-SNE <br>
# Purpose:
# - Check if feature selection makes responder/non-responder easier to distinguish
# - Visualizing the underlying structure of data

# %%
data.head()
# Out:
#           MSKCC  Sarc  Rhab  Number_of_Prior_Therapies   Age   ORR     ACAP1  \
# 0     FAVORABLE     0     0                          1  69.0    SD  33.99747
# 1     FAVORABLE     0     0                          1  61.0    SD  31.71281
# 2     FAVORABLE     0     0                          2  61.0  CRPR  31.73848
# 3  INTERMEDIATE     0     0                          1  61.0    PD  30.55362
# 4  INTERMEDIATE     0     0                          1  59.0    SD  31.11186
#
#        ACCS     ACCSL     ADCY5  ...      UCP2     VEGFA  ZDHHC20P3    ZDHHC7  \
# 0  32.20615  24.06116  30.91315  ...  35.08916  37.12501   20.95143  34.26101
# 1  32.80117  20.57774  30.87107  ...  34.37333  37.90405   20.95143  34.75033
# 2  32.27727  20.57774  32.29066  ...  34.55823  38.00575   20.95143  33.93191
# 3  32.44389  23.35166  34.22764  ...  35.16243  38.85681   23.38186  34.93732
# 4  30.61340  20.57774  33.46771  ...  33.60995  40.34498   20.95143  33.99614
#
#      ZNF433  ORR_binary  Arm_NIVOLUMAB  \
# 0  32.57309           0           True
# 1  29.95693           0          False
# 2  31.48046           1          False
# 3  33.32286           0           True
# 4  32.66356           0           True
#
#    Tumor_Sample_Primary_or_Metastasis_PRIMARY  Sex_M  MSKCC_num
# 0                                       False   True          2
# 1                                       False   True          2
# 2                                        True   True          2
# 3                                        True   True          1
# 4                                        True   True          1
#
# [5 rows x 162 columns]

# %%
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# Assuming we have a binary label for Responder / Non-Responder
y_binary = data["ORR_binary"].values
# Standardize the data
X_std = StandardScaler().fit_transform(X_high_variance_df)
X_tsne = TSNE(n_components=2, random_state=42).fit_transform(X_std)

tsne_df = pd.DataFrame(X_tsne, columns=['TSNE1', 'TSNE2'])
tsne_df['Label'] = y_binary

plt.figure(figsize=(8,6))
sns.scatterplot(data=tsne_df, x='TSNE1', y='TSNE2', hue='Label', palette='Set2')
plt.title("t-SNE Visualization After Feature Selection")
plt.show()

# %% [markdown]
# ### Step4. First time build the Decision Tree model

# %% [markdown]
# I found data is imbalance, so I used Class-weighted here in Decision Tree Classifier.

# %%
# 1. Split the dataset into training and testing sets
# Remove target variables ("ORR", "ORR_binary"),  and "MSKCC", and all gene columns from data
## But add gene_df_filtered to X
exclude_cols = ["ORR", "ORR_binary", "Arm", "MSKCC"] + gene_features
clinical_cols = [col for col in data.columns if col not in exclude_cols]
X = pd.concat([data[clinical_cols].reset_index(drop=True), gene_df_filtered.reset_index(drop=True)], axis=1)
y = data["ORR_binary"]  # Define target variable

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y,  random_state=42)
## 20% for test, 80% for train
### random_state=42:  is used to set a fixed random seed, 
# ### ensuring that the results remain consistent across different runs of the code.


# 2. Create a Decision Tree model (use class_weight="balanced" to handle class imbalance)
model = DecisionTreeClassifier(class_weight="balanced", 
                                random_state=42)
## class_weight="balanced": allow Decision Tree to adjust data balance automatically
### if without this setting, the model may only learn 0, and ignore 1

# 3. Train the model
model.fit(X_train, y_train)

# 4. Make predictions
y_pred = model.predict(X_test)
## use X_test to predict y
## y_pred contains 0 and 1
### model.predict() creates an array, there are 0 or 1
### The length of y_pred is equal to the number of samples in X_test, 
# ### representing the modeil's predicted values for each test sample.

# 5. Evaluate the model (using Accuracy, Precision, Recall, and F1-score)
print("Accuracy of test set:", accuracy_score(y_test, y_pred))
print("Precision of test set:", precision_score(y_test, y_pred))
print("Recall of test set:", recall_score(y_test, y_pred))
print("F1-score of test set:", f1_score(y_test, y_pred))
# Out:
# Accuracy of test set: 0.7307692307692307
# Precision of test set: 0.2857142857142857
# Recall of test set: 0.5
# F1-score of test set: 0.36363636363636365

# %%
y_pred_train = model.predict(X_train)
# 5. Evaluate the model (using Accuracy, Precision, Recall, and F1-score)
print("Accuracy of train set:", accuracy_score(y_train, y_pred_train))
print("Precision of train set:", precision_score(y_train, y_pred_train))
print("Recall of train set:", recall_score(y_train, y_pred_train))
print("F1-score of train set:", f1_score(y_train, y_pred_train))
# Out:
# Accuracy of train set: 1.0
# Precision of train set: 1.0
# Recall of train set: 1.0
# F1-score of train set: 1.0

# %%
print("Decision Tree depth:", model.get_depth())
print("Number of leaves:", model.get_n_leaves())
# Out:
# Decision Tree depth: 14
# Number of leaves: 30

# %% [markdown]
# cross_val_score for whole dataset

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)


accuracy_scores = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
precision_scores = cross_val_score(model, X, y, cv=cv, scoring='precision')
recall_scores = cross_val_score(model, X, y, cv=cv, scoring='recall')
f1_scores = cross_val_score(model, X, y, cv=cv, scoring='f1')

print("Train CV Accuracy:  {:.3f} ± {:.3f}".format(accuracy_scores.mean(), accuracy_scores.std()))
print("Train CV Precision: {:.3f} ± {:.3f}".format(precision_scores.mean(), precision_scores.std()))
print("Train CV Recall:    {:.3f} ± {:.3f}".format(recall_scores.mean(), recall_scores.std()))
print("Train CV F1 Score:  {:.3f} ± {:.3f}".format(f1_scores.mean(), f1_scores.std()))
# Out:
# Train CV Accuracy:  0.727 ± 0.034
# Train CV Precision: 0.135 ± 0.092
# Train CV Recall:    0.157 ± 0.102
# Train CV F1 Score:  0.142 ± 0.089

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(48, 20))  
plot_tree(model, feature_names=X.columns, filled=True, fontsize=12)
plt.title("Tree Structure: Original Decision Tree (only clinical data)")
plt.show()

# %% [markdown]
# Just want to make sure the value = [0,1] (Non-responder, Responder)

# %%
print(model.classes_)
# Out:
# [0 1]

# %%
# Predict on the test set
# The probability that the model predicts the positive class (responder)
y_pred = model.predict(X_test)

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[34 10]
#  [ 4  4]]

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Non-Responder", "Responder"], yticklabels=["Non-Responder", "Responder"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix of Decision Tree after feature selection (with gene data)")
plt.show()

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix

y_cv_pred = cross_val_predict(model, X, y, cv=5)


cm_cv = confusion_matrix(y, y_cv_pred)
print("Cross-Validated Confusion Matrix (on training set):\n", cm_cv)

plt.figure(figsize=(6, 4))
sns.heatmap(cm_cv, annot=True, fmt="d", cmap="Greens", 
            xticklabels=["Non-Responder", "Responder"], 
            yticklabels=["Non-Responder", "Responder"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix of Original Decision Tree_Cross-validation (with gene data)")
plt.show()
# Out:
# Cross-Validated Confusion Matrix (on training set):
#  [[185  34]
#  [ 34   4]]

# %% [markdown]
# Extract feature importances from the model

# %%
# Extract feature importances from the model
feature_importances = model.feature_importances_

# Create a DataFrame to display feature names and their importance
importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importances
})

# Sort the features by importance in descending order
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Display the top features
print(importance_df.head(20))  # Display top 10 important features
# Out:
#                       Feature    Importance
# 72                   LRRC37A3  1.755146e-01
# 49                      UCHL1  1.014306e-01
# 86                    FAM174A  9.570065e-02
# 36                     SUCNR1  8.359133e-02
# 4               Arm_NIVOLUMAB  8.044442e-02
# 39                    LRRC37A  8.007191e-02
# 42                      SIMC1  7.157360e-02
# 69                   DPP9.AS1  5.325919e-02
# 12                    CACNA1A  5.262922e-02
# 30                      BICD1  5.035850e-02
# 71                     LRRC31  3.052981e-02
# 66                       HFM1  2.908957e-02
# 78                     CCDC30  2.297031e-02
# 35                     LRRC32  2.160936e-02
# 1                        Rhab  2.014181e-02
# 53                 LRRC37A14P  1.080264e-02
# 2   Number_of_Prior_Therapies  1.052632e-02
# 90                     DLGAP5  9.756098e-03
# 19                     LRRC3B  9.769963e-16
# 61                   ARHGAP42  2.766041e-16

# %% [markdown]
# Drawing learning curve

# %%
from sklearn.model_selection import learning_curve, StratifiedKFold

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Define the range of training sizes
train_sizes = np.linspace(0.1, 1.0, 10)

# Calculate the learning curve
train_sizes, train_scores, test_scores = learning_curve(
    model, X, y, cv=cv, scoring='f1', train_sizes=train_sizes, n_jobs=-1
)

# Calculate the mean and standard deviation of training and test scores
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plot the learning curve
plt.figure(figsize=(8, 6))
plt.plot(train_sizes, train_scores_mean, label="Training Score", color="blue", marker="o")
plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.2, color="blue")
plt.plot(train_sizes, test_scores_mean, label="Cross-Validation Score", color="green", marker="o")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.2, color="green")
plt.title("Learning Curve: Decision Tree after feature selection (with gene data)")
plt.xlabel("Training Set Size")
plt.ylabel("F1 Score")
plt.legend(loc="best")
plt.grid()
plt.show()

# %%
from sklearn.model_selection import cross_val_score

# Training score
training_score = model.score(X, y)
print("Training Score:", training_score)

# Cross-validation score
cv_scores = cross_val_score(model, X, y, cv=cv, scoring='f1')
print("Cross-Validation Scores:", cv_scores)
print("Mean Cross-Validation Score:", cv_scores.mean())
# Out:
# Training Score: 0.9455252918287937
# Cross-Validation Scores: [0.26666667 0.125      0.         0.2        0.11764706]
# Mean Cross-Validation Score: 0.14186274509803923

# %% [markdown]
#  ### Step.5 Compare the selected genes with a supervised method such as ANOVA

# %%
from sklearn.feature_selection import SelectKBest, f_classif
import pandas as pd

# gene_df_filtered = (after selected) gene features（DataFrame）
# y = target variable (e.g., ORR_binary or ORR_3class)（Series）

# Apply ANOVA (f_classif)
anova_selector = SelectKBest(score_func=f_classif, k='all')  # 'all' to get all features
anova_selector.fit(gene_df_filtered, y)

# show the results in a DataFrame
anova_scores = pd.DataFrame({
    'Gene': gene_df_filtered.columns,
    'F_score': anova_selector.scores_,
    'p_value': anova_selector.pvalues_
}).sort_values(by='F_score', ascending=False)

# show the top 10 features
print(anova_scores.head(10))
# Out:
#          Gene   F_score   p_value
# 70     CCDC30  8.528875  0.003808
# 38    DPH5.DT  5.986825  0.015089
# 34      SIMC1  3.818352  0.051787
# 72  BMAL2.AS1  3.336352  0.068934
# 24    CCDC146  3.137889  0.077687
# 32      GCOM1  2.781733  0.096572
# 64   LRRC37A3  2.750427  0.098458
# 37     CCT7P1  2.603572  0.107860
# 41      UCHL1  2.583182  0.109242
# 39    FAM170A  2.521679  0.113530

# %% [markdown]
# Compare ANOVA ang Variance/Correlation result

# %%
# selected genes based on ANOVA
anova_genes = anova_scores[anova_scores['F_score'] > 3]['Gene'].tolist()  # Adjust the threshold as needed

# selected genes from Variance/Correlation
filtered_genes = set(gene_df_filtered.columns)

# Convert anova_genes to set for set operations
anova_genes_set = set(anova_genes)

# intersection of selected genes
common_genes = anova_genes_set & filtered_genes

# only selected by ANOVA
only_anova = anova_genes_set - filtered_genes

# only selected by Variance/Correlation
only_filtered = filtered_genes - anova_genes_set

# %%
print(" Genes selected by both ANOVA and Variance/Correlation:")
print(sorted(common_genes))

print("Genes only selected by ANOVA:")
print(sorted(only_anova))

print("Genes only selected by Variance/Correlation:")
print(sorted(only_filtered))
# Out:
#  Genes selected by both ANOVA and Variance/Correlation:
# ['BMAL2.AS1', 'CCDC146', 'CCDC30', 'DPH5.DT', 'SIMC1']
# Genes only selected by ANOVA:
# []
# Genes only selected by Variance/Correlation:
# ['ACAP1', 'ACCS', 'ACCSL', 'ADCY5', 'AHRR', 'ARHGAP42', 'ATXN3L', 'BARX2', 'BICD1', 'BPY2B', 'BTBD10P1', 'C3orf20', 'CACNA1A', 'CACNG2', 'CAP1P2', 'CCT7P1', 'CCT7P2', 'CDS1', 'CEACAM6', 'CHST4', 'CLDN6', 'CLSPN', 'CNR1', 'CPPED1', 'CRPP1', 'CYSRT1', 'DCAF12L1', 'DCAF12L2', 'DCAF13P1', 'DLGAP5', 'DOC2A', 'DPP4', 'DPP9.AS1', 'DSPP', 'ENAHP1', 'ENAM', 'EPHB2', 'EXO1', 'FAM13A.AS1', 'FAM170A', 'FAM174A', 'FLT3', 'FLT3LG', 'GADD45A', 'GAGE2E', 'GCOM1', 'GOT2P1', 'GOT2P3', 'GPR42', 'HFM1', 'HLA.G', 'KRBA2', 'KRTAP2.3', 'L1CAM', 'LRRC3', 'LRRC30', 'LRRC31', 'LRRC32', 'LRRC34', 'LRRC36', 'LRRC37A', 'LRRC37A13P', 'LRRC37A14P', 'LRRC37A15P', 'LRRC37A2', 'LRRC37A3', 'LRRC37A6P', 'LRRC38', 'LRRC39', 'LRRC3B', 'LRRC3C', 'MASP1', 'MYOC', 'MYOCD', 'NECAP1P2', 'PSMC1P10', 'RAB3B', 'SUCNR1', 'TENM3', 'TSSK3', 'UCHL1', 'ZNF433']

# %% [markdown]
# ### Step6. Complexity reduction

# %% [markdown]
# max_depth=7,<br>min_samples_split=5,
# <br>min_samples_leaf=7

# %%
# 1. Split the dataset into training and testing sets
# Remove target variables ("ORR", "ORR_binary"),  and "MSKCC", and all gene columns from data
## But add gene_df_filtered to X
exclude_cols = ["ORR", "ORR_binary", "Arm", "MSKCC"] + gene_features
clinical_cols = [col for col in data.columns if col not in exclude_cols]
X = pd.concat([data[clinical_cols].reset_index(drop=True), gene_df_filtered.reset_index(drop=True)], axis=1)
y = data["ORR_binary"]  # Define target variable

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y,  random_state=42)
## 20% for test, 80% for train
### random_state=42:  is used to set a fixed random seed, 
# ### ensuring that the results remain consistent across different runs of the code.


# 2. Create a Decision Tree model (use class_weight="balanced" to handle class imbalance)
model = DecisionTreeClassifier(class_weight="balanced", 
                                random_state=42,
                                max_depth=7,                        min_samples_split=5,
min_samples_leaf=7,

)
## class_weight="balanced": allow Decision Tree to adjust data balance automatically
### if without this setting, the model may only learn 0, and ignore 1

# 3. Train the model
model.fit(X_train, y_train)

# 4. Make predictions
y_pred = model.predict(X_test)
## use X_test to predict y
## y_pred contains 0 and 1
### model.predict() creates an array, there are 0 or 1
### The length of y_pred is equal to the number of samples in X_test, 
# ### representing the modeil's predicted values for each test sample.

# 5. Evaluate the model (using Accuracy, Precision, Recall, and F1-score)
print("Accuracy of test set:", accuracy_score(y_test, y_pred))
print("Precision of test set:", precision_score(y_test, y_pred))
print("Recall of test set:", recall_score(y_test, y_pred))
print("F1-score of test set:", f1_score(y_test, y_pred))
# Out:
# Accuracy of test set: 0.5769230769230769
# Precision of test set: 0.1111111111111111
# Recall of test set: 0.25
# F1-score of test set: 0.15384615384615385

# %%
y_pred_train = model.predict(X_train)
# 5. Evaluate the model (using Accuracy, Precision, Recall, and F1-score)
print("Accuracy of train set:", accuracy_score(y_train, y_pred_train))
print("Precision of train set:", precision_score(y_train, y_pred_train))
print("Recall of train set:", recall_score(y_train, y_pred_train))
print("F1-score of train set:", f1_score(y_train, y_pred_train))


print("Decision Tree depth:", model.get_depth())
print("Number of leaves:", model.get_n_leaves())
# Out:
# Accuracy of train set: 0.848780487804878
# Precision of train set: 0.49122807017543857
# Recall of train set: 0.9333333333333333
# F1-score of train set: 0.6436781609195402
# Decision Tree depth: 7
# Number of leaves: 13

# %% [markdown]
# Cross-validation for the whole dataset

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)


accuracy_scores = cross_val_score(model, X, y, cv=cv, scoring='accuracy')
precision_scores = cross_val_score(model, X, y, cv=cv, scoring='precision')
recall_scores = cross_val_score(model, X, y, cv=cv, scoring='recall')
f1_scores = cross_val_score(model, X, y, cv=cv, scoring='f1')

print("Train CV Accuracy:  {:.3f} ± {:.3f}".format(accuracy_scores.mean(), accuracy_scores.std()))
print("Train CV Precision: {:.3f} ± {:.3f}".format(precision_scores.mean(), precision_scores.std()))
print("Train CV Recall:    {:.3f} ± {:.3f}".format(recall_scores.mean(), recall_scores.std()))
print("Train CV F1 Score:  {:.3f} ± {:.3f}".format(f1_scores.mean(), f1_scores.std()))
# Out:
# Train CV Accuracy:  0.627 ± 0.065
# Train CV Precision: 0.145 ± 0.041
# Train CV Recall:    0.293 ± 0.069
# Train CV F1 Score:  0.191 ± 0.044

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(48, 20))  
plot_tree(model, feature_names=X.columns, filled=True, fontsize=12)
plt.title("Tree Structure: Original Decision Tree (only clinical data)")
plt.show()

# %%
# Predict on the test set
# The probability that the model predicts the positive class (responder)
y_pred = model.predict(X_test)

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Non-Responder", "Responder"], yticklabels=["Non-Responder", "Responder"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix of Decision Tree after feature selection and reducing complexity (with gene data)")
plt.show()
# Out:
# Confusion Matrix:
#  [[28 16]
#  [ 6  2]]

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix

y_cv_pred = cross_val_predict(model, X, y, cv=5)


cm_cv = confusion_matrix(y, y_cv_pred)
print("Cross-Validated Confusion Matrix (on training set):\n", cm_cv)

plt.figure(figsize=(6, 4))
sns.heatmap(cm_cv, annot=True, fmt="d", cmap="Greens", 
            xticklabels=["Non-Responder", "Responder"], 
            yticklabels=["Non-Responder", "Responder"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix of Decision Tree after feature selection and reducing complexity_Cross-validation (with gene data)")
plt.show()
# Out:
# Cross-Validated Confusion Matrix (on training set):
#  [[161  58]
#  [ 31   7]]

# %%
# Extract feature importances from the model
feature_importances = model.feature_importances_

# Create a DataFrame to display feature names and their importance
importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': feature_importances
})

# Sort the features by importance in descending order
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Display the top features
print(importance_df.head(20))  # Display top 10 important features
# Out:
#           Feature    Importance
# 72       LRRC37A3  2.584068e-01
# 86        FAM174A  2.205746e-01
# 49          UCHL1  1.493344e-01
# 4   Arm_NIVOLUMAB  1.184368e-01
# 48      LRRC37A6P  1.053764e-01
# 39        LRRC37A  6.367044e-02
# 92           ACCS  4.208148e-02
# 85         CYSRT1  2.065905e-02
# 16         LRRC34  1.728128e-02
# 61       ARHGAP42  4.178696e-03
# 66           HFM1  1.438413e-15
# 52         CACNG2  0.000000e+00
# 51         GOT2P3  0.000000e+00
# 67          KRBA2  0.000000e+00
# 65          ACAP1  0.000000e+00
# 64         LRRC38  0.000000e+00
# 63          CRPP1  0.000000e+00
# 62          MYOCD  0.000000e+00
# 59          TENM3  0.000000e+00
# 60          ACCSL  0.000000e+00

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Define the range of training sizes
train_sizes = np.linspace(0.1, 1.0, 10)

# Calculate the learning curve
train_sizes, train_scores, test_scores = learning_curve(
    model, X, y, cv=cv, scoring='f1', train_sizes=train_sizes, n_jobs=-1
)

# Calculate the mean and standard deviation of training and test scores
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plot the learning curve
plt.figure(figsize=(8, 6))
plt.plot(train_sizes, train_scores_mean, label="Training Score", color="blue", marker="o")
plt.fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.2, color="blue")
plt.plot(train_sizes, test_scores_mean, label="Cross-Validation Score", color="green", marker="o")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.2, color="green")
plt.title("Learning Curve: Confusion Matrix of Decision Tree after feature selection and reducing complexity (with gene data)")
plt.xlabel("Training Set Size")
plt.ylabel("F1 Score")
plt.legend(loc="best")
plt.grid()
plt.show()

# %%
from sklearn.model_selection import cross_val_score

# Training score
training_score = model.score(X, y)
print("Training Score:", training_score)

# Cross-validation score
cv_scores = cross_val_score(model, X, y, cv=cv, scoring='f1')
print("Cross-Validation Scores:", cv_scores)
print("Mean Cross-Validation Score:", cv_scores.mean())
# Out:
# Training Score: 0.7937743190661478
# Cross-Validation Scores: [0.14814815 0.14814815 0.17391304 0.26086957 0.22222222]
# Mean Cross-Validation Score: 0.19066022544283412

# %% [markdown]
# ### Step.7 Apply Anova after reduing complexity

# %%
from sklearn.feature_selection import SelectKBest, f_classif
import pandas as pd

# gene_df_filtered = (after selected) gene features（DataFrame）
# y = target variable (e.g., ORR_binary or ORR_3class)（Series）

# Apply ANOVA (f_classif)
anova_selector = SelectKBest(score_func=f_classif, k='all')  # 'all' to get all features
anova_selector.fit(gene_df_filtered, y)

# show the results in a DataFrame
anova_scores = pd.DataFrame({
    'Gene': gene_df_filtered.columns,
    'F_score': anova_selector.scores_,
    'p_value': anova_selector.pvalues_
}).sort_values(by='F_score', ascending=False)

# show the top 10 features
print(anova_scores.head(10))
# Out:
#          Gene   F_score   p_value
# 70     CCDC30  8.528875  0.003808
# 38    DPH5.DT  5.986825  0.015089
# 34      SIMC1  3.818352  0.051787
# 72  BMAL2.AS1  3.336352  0.068934
# 24    CCDC146  3.137889  0.077687
# 32      GCOM1  2.781733  0.096572
# 64   LRRC37A3  2.750427  0.098458
# 37     CCT7P1  2.603572  0.107860
# 41      UCHL1  2.583182  0.109242
# 39    FAM170A  2.521679  0.113530

# %%
# all genes selected by ANOVA (after filtering)
## anova_genes = set(anova_scores['Gene'])

# after VarianceThreshold + correlation filtering, we have gene_df_filtered
## filtered_genes = set(gene_df_filtered.columns)

# find common genes, only in anova_genes, and only in filtered_genes
## common_genes = anova_genes & filtered_genes
## only_anova = anova_genes - filtered_genes
## only_filtered = filtered_genes - anova_genes

# %%
print(" Genes selected by both ANOVA and Variance/Correlation:")
print(sorted(common_genes))

print("Genes only selected by ANOVA:")
print(sorted(only_anova))

print("Genes only selected by Variance/Correlation:")
print(sorted(only_filtered))
# Out:
#  Genes selected by both ANOVA and Variance/Correlation:
# ['BMAL2.AS1', 'CCDC146', 'CCDC30', 'DPH5.DT', 'SIMC1']
# Genes only selected by ANOVA:
# []
# Genes only selected by Variance/Correlation:
# ['ACAP1', 'ACCS', 'ACCSL', 'ADCY5', 'AHRR', 'ARHGAP42', 'ATXN3L', 'BARX2', 'BICD1', 'BPY2B', 'BTBD10P1', 'C3orf20', 'CACNA1A', 'CACNG2', 'CAP1P2', 'CCT7P1', 'CCT7P2', 'CDS1', 'CEACAM6', 'CHST4', 'CLDN6', 'CLSPN', 'CNR1', 'CPPED1', 'CRPP1', 'CYSRT1', 'DCAF12L1', 'DCAF12L2', 'DCAF13P1', 'DLGAP5', 'DOC2A', 'DPP4', 'DPP9.AS1', 'DSPP', 'ENAHP1', 'ENAM', 'EPHB2', 'EXO1', 'FAM13A.AS1', 'FAM170A', 'FAM174A', 'FLT3', 'FLT3LG', 'GADD45A', 'GAGE2E', 'GCOM1', 'GOT2P1', 'GOT2P3', 'GPR42', 'HFM1', 'HLA.G', 'KRBA2', 'KRTAP2.3', 'L1CAM', 'LRRC3', 'LRRC30', 'LRRC31', 'LRRC32', 'LRRC34', 'LRRC36', 'LRRC37A', 'LRRC37A13P', 'LRRC37A14P', 'LRRC37A15P', 'LRRC37A2', 'LRRC37A3', 'LRRC37A6P', 'LRRC38', 'LRRC39', 'LRRC3B', 'LRRC3C', 'MASP1', 'MYOC', 'MYOCD', 'NECAP1P2', 'PSMC1P10', 'RAB3B', 'SUCNR1', 'TENM3', 'TSSK3', 'UCHL1', 'ZNF433']

# %%
# selected genes based on ANOVA
anova_all = SelectKBest(score_func=f_classif, k='all') # 'all' to get all features
anova_all.fit(gene_df, y)
anova_all_scores = pd.DataFrame({
    'Gene': gene_df.columns,
    'F_score': anova_all.scores_,
    'p_value': anova_all.pvalues_
}).sort_values(by='F_score', ascending=False)

# compare the ANOVA scores before and after filtering
# the anova scores before filtering
anova_all_scores = anova_all_scores.set_index('Gene')
# the anova scores after filtering
anova_filtered_scores = anova_scores.set_index('Gene')
# combine the two DataFrames for comparison
anova_comparison = anova_all_scores.join(anova_filtered_scores, lsuffix='_all', rsuffix='_filtered', how='outer')
# print the comparison DataFrame
print(anova_comparison.head(20))  # show the top 20 genes for comparison
# Out:
#             F_score_all  p_value_all  F_score_filtered  p_value_filtered
# Gene
# ACAP1          1.288595     0.257373          1.288595          0.257373
# ACCS           0.015000     0.902620          0.015000          0.902620
# ACCSL          0.533432     0.465838          0.533432          0.465838
# ADCY5          0.391502     0.532071          0.391502          0.532071
# AHRR           0.465246     0.495801          0.465246          0.495801
# AK3P4          0.087439     0.767700               NaN               NaN
# ARHGAP42       0.521418     0.470899          0.521418          0.470899
# ARPC1B         0.785001     0.376451               NaN               NaN
# ATP6V1G1P2     0.214572     0.643603               NaN               NaN
# ATXN3L         0.231800     0.630605          0.231800          0.630605
# BARX2          0.498834     0.480658          0.498834          0.480658
# BICD1          0.325472     0.568840          0.325472          0.568840
# BICD1P1        0.395263     0.530108               NaN               NaN
# BMAL2.AS1      3.336352     0.068934          3.336352          0.068934
# BPY2B          1.817282     0.178833          1.817282          0.178833
# BTBD10         0.078953     0.778950               NaN               NaN
# BTBD10P1       1.210797     0.272212          1.210797          0.272212
# C3orf20        0.734178     0.392337          0.734178          0.392337
# CACNA1A        0.002298     0.961806          0.002298          0.961806
# CACNG2         0.002600     0.959373          0.002600          0.959373
